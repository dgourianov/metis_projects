# %%
import pandas as pd
import numpy as np

from bs4 import BeautifulSoup
import requests

# %%
!

# %%
age = pd.read_csv('../Data/countries_regions.csv')

# %%
age.head()
# Out:
#   ISO3 Code         Country               ILO Region  \
# 0       NaN             NaN                      NaN
# 1       AFG     Afghanistan     Asia and the Pacific
# 2       ALB         Albania  Europe and Central Asia
# 3       DZA         Algeria                   Africa
# 4       ASM  American Samoa     Asia and the Pacific
#
#                    ILO Subregion - Broad ILO Subregion - Detailed  \
# 0                                    NaN                      NaN
# 1                          Southern Asia            Southern Asia
# 2  Northern, Southern and Western Europe          Southern Europe
# 3                        Northern Africa          Northern Africa
# 4     South-Eastern Asia and the Pacific          Pacific Islands
#
#   World Bank Income Group(1) Is ILO member? Included in ILO estimates?  \
# 0                        NaN            NaN        Employment by class
# 1                 Low income              Y                          Y
# ...

# %%
age = age.iloc[1:,[1,4]]
age
# Out:
#                        Country ILO Subregion - Detailed
# 1                  Afghanistan            Southern Asia
# 2                      Albania          Southern Europe
# 3                      Algeria          Northern Africa
# 4               American Samoa          Pacific Islands
# 5                      Andorra          Southern Europe
# ..                         ...                      ...
# 233  Wallis and Futuna Islands          Pacific Islands
# 234             Western Sahara          Northern Africa
# 235                      Yemen              Arab States
# 236                     Zambia           Eastern Africa
# 237                   Zimbabwe           Eastern Africa
#
# [237 rows x 2 columns]

# %%
age.rename(columns={'Country':'country','ILO Subregion - Detailed':'region'}, inplace=True)

# %%
age.head()
# Out:
#           country           region
# 1     Afghanistan    Southern Asia
# 2         Albania  Southern Europe
# 3         Algeria  Northern Africa
# 4  American Samoa  Pacific Islands
# 5         Andorra  Southern Europe

# %%
age.isnull().sum()
# Out:
# country    0
# region     0
# dtype: int64

# %%
age.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237 entries, 1 to 237
# Data columns (total 2 columns):
# country    237 non-null object
# region     237 non-null object
# dtypes: object(2)
# memory usage: 3.8+ KB

# %%
# %store -r countries_dict
age['country'] = age['country'].replace(countries_dict)
age
# Out:
#                        country           region
# 1                  Afghanistan    Southern Asia
# 2                      Albania  Southern Europe
# 3                      Algeria  Northern Africa
# 4               American Samoa  Pacific Islands
# 5                      Andorra  Southern Europe
# ..                         ...              ...
# 233  Wallis and Futuna Islands  Pacific Islands
# 234             Western Sahara  Northern Africa
# 235                      Yemen      Arab States
# 236                     Zambia   Eastern Africa
# 237                   Zimbabwe   Eastern Africa
#
# [237 rows x 2 columns]

# %%
# %store -r countries
#checking for different versions of counties names
age.country[~age.country.isin(countries)].head(60)
# Out:
# 2                                        Albania
# 4                                 American Samoa
# 7                                       Anguilla
# 11                                         Aruba
# 23                                       Bermuda
# 29                        British Virgin Islands
# 38                                Cayman Islands
# 41                               Channel Islands
# 48                                  Cook Islands
# 52                                       Curaçao
# 58                                      Dominica
# 67                                Faeroe Islands
# 68                   Falkland Islands (Malvinas)
# 72                                 French Guiana
# 73                              French Polynesia
# 79                                     Gibraltar
# 81                                     Greenland
# 83                                    Guadeloupe
# 84                                          Guam
# ...

# %%
#lets save/pickle our 'age' dataframe
import pickle

with open('../Data/Pickled/regions.pkl', 'wb') as picklefile:
    pickle.dump(age, picklefile)
