# %% [markdown]
# ### Scraping BMI

# %%
# Necessary imports
import pandas as pd
import numpy as np

from bs4 import BeautifulSoup
import requests

# %%
pd.set_option('display.max_rows', 200)

# %%
#wiki website 
url = 'https://en.wikipedia.org/wiki/List_of_countries_by_body_mass_index' 
response = requests.get(url)

# %%
response.status_code #200 = success!
# Out:
# 200

# %%
response.text[:1000]  #First 1000 characters of the HTML
# Out:
# '\n<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>List of countries by body mass index - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"XpSWqgpAICIAALtXbwQAAAAQ","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"List_of_countries_by_body_mass_index","wgTitle":"List of countries by body mass index","wgCurRevisionId":950081097,"wgRevisionId":950081097,"wgArticleId":49541051,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Accuracy disputes from January 2020","All accuracy disputes","Health by country","Obesity","Lists of 
# ...

# %%
page = response.text

# %%
soup = BeautifulSoup(page, "lxml")

# %%
print (soup.prettify()[:2000])
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of countries by body mass index - Wikipedia
#   </title>
#   <script>
# ...

# %%
#looking for a table 
table = soup.find(class_='wikitable')
print(table)
# Out:
# <table class="wikitable sortable" style="text-align:center">
# <tbody><tr style="background:#ececec; vertical-align:top;">
# <th>Country</th>
# <th>Overall<br/>rank</th>
# <th>Overall mean <br/><a href="/wiki/Body_mass_index" title="Body mass index">BMI</a> (kg/m<sup>2</sup>)</th>
# <th>Female <br/>rank</th>
# <th>Female mean <br/><a href="/wiki/Body_mass_index" title="Body mass index">BMI</a> (kg/m<sup>2</sup>)</th>
# <th>Male <br/>rank</th>
# <th>Male mean <br/><a href="/wiki/Body_mass_index" title="Body mass index">BMI</a> (kg/m<sup>2</sup>)
# </th></tr>
# <tr>
# ...

# %%
#getting header
th = table.find_all('th')
for i in th:
    print (i.text)
# Out:
# Country
# Overallrank
# Overall mean BMI (kg/m2)
# Female rank
# Female mean BMI (kg/m2)
# Male rank
# Male mean BMI (kg/m2)

# %%
#getting all the  rows of the table
table_rows = table.find_all('tr')

# %%
# creating list of lists (aka list of rows)
table = []

for tr in table_rows:
    td = tr.find_all('td')
    row = [i.text.strip() for i in td]
    table.append(row)
    print(row)   #regions will have to be removed!!!
# Out:
# []
# ['Tonga', '1', '31.9', '1', '33.5', '1', '30.4']
# ['Samoa', '2', '31.7', '1', '33.5', '2', '29.9']
# ['Kuwait', '3', '30', '5', '30.8', '3', '29.5']
# ['Saint Kitts and Nevis', '4', '29.7', '4', '30.9', '12', '28.4']
# ['Saint Lucia', '5', '29.6', '8', '30.2', '6', '28.9']
# ['Kiribati', '5', '29.6', '7', '30.5', '9', '28.7']
# ['Palau', '7', '29.4', '18', '29.5', '4', '29.4']
# ['Federated States of Micronesia', '7', '29.4', '3', '31', '22', '27.8']
# ['Tuvalu', '9', '29.3', '13', '29.9', '9', '28.7']
# ['Qatar', '10', '29.2', '10', '30.1', '5', '29']
# ['Marshall Islands', '10', '29.2', '11', '30', '12', '28.4']
# ['Egypt', '10', '29.2', '6', '30.7', '26', '27.6']
# ['United Arab Emirates', '13', '29', '14', '29.7', '11', '28.6']
# ['Jordan', '14', '28.9', '14', '29.7', '15', '28.2']
# ['Belize', '14', '28.9', '8', '30.2', '26', '27.6']
# ['United States', '16', '28.8', '26', '28.8', '7', '28.8']
# ['The Bahamas', '16', '28.8', '16', '29.6', '16', '28']
# ...

# %%
#converting into a DataFrame
age = pd.DataFrame(table)
age.head()
# Out:
#                        0     1     2     3     4     5     6
# 0                   None  None  None  None  None  None  None
# 1                  Tonga     1  31.9     1  33.5     1  30.4
# 2                  Samoa     2  31.7     1  33.5     2  29.9
# 3                 Kuwait     3    30     5  30.8     3  29.5
# 4  Saint Kitts and Nevis     4  29.7     4  30.9    12  28.4

# %%
#removing two rows and two columns
age = age.iloc[1:191,:3]

# %%
age.columns = ['country', 'rank', 'obesity']

# %%
age.head(200)
# Out:
#                               country rank obesity
# 1                               Tonga    1    31.9
# 2                               Samoa    2    31.7
# 3                              Kuwait    3      30
# 4               Saint Kitts and Nevis    4    29.7
# 5                         Saint Lucia    5    29.6
# 6                            Kiribati    5    29.6
# 7                               Palau    7    29.4
# 8      Federated States of Micronesia    7    29.4
# 9                              Tuvalu    9    29.3
# 10                              Qatar   10    29.2
# 11                   Marshall Islands   10    29.2
# 12                              Egypt   10    29.2
# 13               United Arab Emirates   13      29
# 14                             Jordan   14    28.9
# 15                             Belize   14    28.9
# 16                      United States   16    28.8
# 17                        The Bahamas   16    28.8
# ...

# %%
age.drop(columns='rank', inplace=True)

# %%
age.isnull().sum()
# Out:
# country    0
# obesity    0
# dtype: int64

# %%
#looks like we have strings as rank and age 
age.dtypes
# Out:
# country    object
# obesity    object
# dtype: object

# %%
age.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190 entries, 1 to 190
# Data columns (total 2 columns):
# country    190 non-null object
# obesity    190 non-null object
# dtypes: object(2)
# memory usage: 3.1+ KB

# %%
#converting strings into numeric 

age['obesity'] = age['obesity'].str.replace('-','').apply(float)
age.dtypes
# Out:
# country     object
# obesity    float64
# dtype: object

# %%
age.shape
# Out:
# (190, 2)

# %%
age.dropna(inplace=True)
age.reset_index(inplace=True, drop=True)

# %%
age.head(100)
# Out:
#                              country  obesity
# 0                              Tonga     31.9
# 1                              Samoa     31.7
# 2                             Kuwait     30.0
# 3              Saint Kitts and Nevis     29.7
# 4                        Saint Lucia     29.6
# 5                           Kiribati     29.6
# 6                              Palau     29.4
# 7     Federated States of Micronesia     29.4
# 8                             Tuvalu     29.3
# 9                              Qatar     29.2
# 10                  Marshall Islands     29.2
# 11                             Egypt     29.2
# 12              United Arab Emirates     29.0
# 13                            Jordan     28.9
# 14                            Belize     28.9
# 15                     United States     28.8
# 16                       The Bahamas     28.8
# 17               Trinidad and Tobago     28.7
# 18                          Barbados     28.7
# ...

# %%
#replacing countries names 
# %store -r countries_dict
age['country'] = age['country'].replace(countries_dict)

# %%
# %store -r countries

# %%
#countries that are not in 'age' file
age.country[~age.country.isin(countries)]
# Out:
# 8            Tuvalu
# 16      The Bahamas
# 52         Dominica
# 67        Swaziland
# 87     Cook Islands
# 88          Albania
# 180     North Korea
# Name: country, dtype: object

# %%
#lets save/pickle our 'age' dataframe
import pickle

with open('../Data/Pickled/bmi.pkl', 'wb') as picklefile:
    pickle.dump(age, picklefile)
