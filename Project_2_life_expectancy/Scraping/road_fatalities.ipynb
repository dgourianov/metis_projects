# %% [markdown]
# ### Scraping democracy level

# %%
# Necessary imports
import pandas as pd
import numpy as np

from bs4 import BeautifulSoup
import requests

# %%
pd.set_option('display.max_rows', 200)

# %%
#wiki website 
url = 'https://en.wikipedia.org/wiki/List_of_countries_by_traffic-related_death_rate'
response = requests.get(url)

# %%
response.status_code #200 = success!
# Out:
# 200

# %%
response.text[:1000]  #First 1000 characters of the HTML
# Out:
# '\n<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>List of countries by traffic-related death rate - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"XpSkoApAICsAAG3pwk8AAADY","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"List_of_countries_by_traffic-related_death_rate","wgTitle":"List of countries by traffic-related death rate","wgCurRevisionId":949686004,"wgRevisionId":949686004,"wgArticleId":22688285,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 Swedish-language sources (sv)","CS1 maint: uses authors paramete
# ...

# %%
page = response.text

# %%
soup = BeautifulSoup(page, "lxml")

# %%
print (soup.prettify()[:2000])
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of countries by traffic-related death rate - Wikipedia
#   </title>
#   <script>
# ...

# %%
#looking for a table 
table = soup.find(class_='wikitable')
print(table)
# Out:
# <table class="wikitable sortable mw-datatable" style="margin-left:auto;margin-right:auto; text-align: right">
# <tbody><tr valign="bottom">
# <th>Country
# </th>
# <th>Continent
# </th>
# <th data-sort-type="number">Road fatalities<br/>per 100,000<br/>inhabitants<br/>per year<sup class="reference" id="cite_ref-datatables_6-1"><a href="#cite_note-datatables-6">[5]</a></sup><sup class="reference" id="cite_ref-WHO2018_3-1"><a href="#cite_note-WHO2018-3">[2]</a></sup>
# </th>
# <th data-sort-type="number">Road fatalities<br/>per 100,000<br/>motor vehicles<sup class="reference" id="cite_ref-datatables_6-2"><a href="#cite_note-datatables-6">[5]</a></sup><sup class="reference" id="cite_ref-WHO2018_3-2"><a href="#cite_note-WHO2018-3">[2]</a></sup>
# </th>
# <th data-sort-type="number">Road fatalities<br/>per 1 billion<br/>vehicle-km<sup class="reference" id="cite_ref-itf2018_7-0"><a href="#cite_note-itf2018-7">[6]</a></sup>
# </th>
# ...

# %%
#getting header
th = table.find_all('th')
for i in th:
    print (i.text)
# Out:
# Country
#
# Continent
#
# Road fatalitiesper 100,000inhabitantsper year[5][2]
#
# Road fatalitiesper 100,000motor vehicles[5][2]
#
# Road fatalitiesper 1 billionvehicle-km[6]
#
# Total fatalitieslatest year(adjusted/estimatedfigures by WHO report)[5][2]
#
# Year, data source(standard source:The WHO report 2015,[3]data from 2013The WHO report 2018,[2]data from 2016)

# %%
#getting all the  rows of the table
table_rows = table.find_all('tr')

# %%
# creating list of lists (aka list of rows)
table = []

for tr in table_rows:
    td = tr.find_all('td')
    row = [i.text.strip() for i in td]
    table.append(row)
    print(row)   #regions will have to be removed!!!
# Out:
# []
# ['World', '', '18.2', '', '', '1,350,000', '2016']
# ['Africa', '', '26.6', '574[7]', '', '246,719[7]', '2016']
# ['Eastern Mediterranean', '', '18.0', '139[7]', '', '122,730[7]', '2016']
# ['Western Pacific', '', '16.9', '69[7]', '', '328,591[7]', '2016']
# ['South-east Asia', '', '20.7', '101[7]', '', '316,080[7]', '2016']
# ['Americas', '', '15.6', '33[7]', '', '153,789[7]', '2016']
# ['Europe', '', '9', '19[7]', '', '85,629[7]', '2018']
# ['Afghanistan', 'Asia', '15.5', '722.4', '', '4,734', '2013']
# ['Albania', 'Europe', '13.6', '107.2', '', '399', '2018']
# ['Algeria', 'Africa', '23.8', '127.8', '', '9,337', '2013']
# ['Andorra', 'Europe', '7.6', '7.9', '', '6', '2013']
# ['Angola', 'Africa', '26.9', '992', '', '5,769', '2013']
# ['Antigua and Barbuda', 'North America', '6.7', '20', '', '6', '2013']
# ['Argentina', 'South America', '13.6', '24.3', '', '5,619', '2013']
# ['Armenia', 'Europe', '17.1', '18.2', '', '499', '2018']
# ...

# %%
#convirting into a DataFrame
age = pd.DataFrame(table)
age.head(200)
# Out:
#                                     0              1           2            3  \
# 0                                None           None        None         None
# 1                               World                       18.2
# 2                              Africa                       26.6       574[7]
# 3               Eastern Mediterranean                       18.0       139[7]
# 4                     Western Pacific                       16.9        69[7]
# 5                     South-east Asia                       20.7       101[7]
# 6                            Americas                       15.6        33[7]
# 7                              Europe                          9        19[7]
# 8                         Afghanistan           Asia        15.5        722.4
# 9                             Albania         Europe        13.6        107.2
# 10                            Algeria         Africa        23.8        127.8
# ...

# %%
#removing two rows and two columns
age = age.iloc[1:,[0,2]]
age
# Out:
#                                     0           2
# 1                               World        18.2
# 2                              Africa        26.6
# 3               Eastern Mediterranean        18.0
# 4                     Western Pacific        16.9
# 5                     South-east Asia        20.7
# 6                            Americas        15.6
# 7                              Europe           9
# 8                         Afghanistan        15.5
# 9                             Albania        13.6
# 10                            Algeria        23.8
# 11                            Andorra         7.6
# 12                             Angola        26.9
# 13                Antigua and Barbuda         6.7
# 14                          Argentina        13.6
# 15                            Armenia        17.1
# 16                          Australia         5.6
# 17                            Austria         5.2
# 18                         Azerbaijan         7.5
# ...

# %%
age.columns = ['country', 'road_fatalities']

# %%
age.head(100)
# Out:
#                               country road_fatalities
# 1                               World            18.2
# 2                              Africa            26.6
# 3               Eastern Mediterranean            18.0
# 4                     Western Pacific            16.9
# 5                     South-east Asia            20.7
# 6                            Americas            15.6
# 7                              Europe               9
# 8                         Afghanistan            15.5
# 9                             Albania            13.6
# 10                            Algeria            23.8
# 11                            Andorra             7.6
# 12                             Angola            26.9
# 13                Antigua and Barbuda             6.7
# 14                          Argentina            13.6
# 15                            Armenia            17.1
# 16                          Australia             5.6
# ...

# %%
age.isnull().sum()
# Out:
# country            0
# road_fatalities    0
# dtype: int64

# %%
#looks like we have strings as rank and age 
age.dtypes
# Out:
# country            object
# road_fatalities    object
# dtype: object

# %%
age.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 1 to 188
# Data columns (total 2 columns):
# country            188 non-null object
# road_fatalities    188 non-null object
# dtypes: object(2)
# memory usage: 3.1+ KB

# %%
#converting strings into numeric 
age=age[~(age['country']=='Taiwan')]
age['road_fatalities'] = age['road_fatalities'].apply(float)
age.dtypes
# Out:
# /home/dgou1218/anaconda3/envs/metis/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# country             object
# road_fatalities    float64
# dtype: object

# %%
age.shape
# Out:
# (187, 2)

# %%
age.dropna(inplace=True)
age.reset_index(inplace=True, drop=True)
# Out:
# /home/dgou1218/anaconda3/envs/metis/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
age.head(100)
# Out:
#                              country  road_fatalities
# 0                              World             18.2
# 1                             Africa             26.6
# 2              Eastern Mediterranean             18.0
# 3                    Western Pacific             16.9
# 4                    South-east Asia             20.7
# 5                           Americas             15.6
# 6                             Europe              9.0
# 7                        Afghanistan             15.5
# 8                            Albania             13.6
# 9                            Algeria             23.8
# 10                           Andorra              7.6
# 11                            Angola             26.9
# 12               Antigua and Barbuda              6.7
# 13                         Argentina             13.6
# 14                           Armenia             17.1
# 15                         Australia              5.6
# ...

# %%
# %store -r countries_dict
age['country'] = age['country'].replace(countries_dict)
# Out:
# /home/dgou1218/anaconda3/envs/metis/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#checking for different versions of counties names
# %store -r countries
age.country[~age.country.isin(countries)]
# Out:
# 1                     Africa
# 2      Eastern Mediterranean
# 3            Western Pacific
# 4            South-east Asia
# 5                   Americas
# 6                     Europe
# 8                    Albania
# 43              Cook Islands
# 52                  Dominica
# 83               Ivory Coast
# 112                   Monaco
# 144               San Marino
# 162                Swaziland
# Name: country, dtype: object

# %%
#lets save/pickle our 'age' dataframe
import pickle

with open('../Data/Pickled/road_fatalities.pkl', 'wb') as picklefile:
    pickle.dump(age, picklefile)
