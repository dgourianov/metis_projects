# %% [markdown]
# ### Scraping Smoking Rates Statistics

# %%
# Necessary imports
import pandas as pd
import numpy as np

from bs4 import BeautifulSoup
import requests

# %%
pd.set_option('display.max_rows', 200)

# %%
#wiki website 
url = 'https://en.wikipedia.org/wiki/List_of_countries_by_cigarette_consumption_per_capita' 
response = requests.get(url)

# %%
response.status_code #200 = success!
# Out:
# 200

# %%
response.text[:1000]  #First 1000 characters of the HTML
# Out:
# '\n<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>List of countries by cigarette consumption per capita - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"XpHtKApAMMIAA2fE@wAAAABA","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"List_of_countries_by_cigarette_consumption_per_capita","wgTitle":"List of countries by cigarette consumption per capita","wgCurRevisionId":949932356,"wgRevisionId":949932356,"wgArticleId":18713424,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles with short description","All articles wit
# ...

# %%
page = response.text

# %%
soup = BeautifulSoup(page, "lxml")

# %%
print (soup.prettify()[:2000])
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of countries by cigarette consumption per capita - Wikipedia
#   </title>
#   <script>
# ...

# %%
#looking for a table 
table = soup.find(class_='wikitable')
print(table)
# Out:
# <table class="wikitable sortable">
# <caption>Cigarette consumption per year per person aged ≥ 15, 2016<sup class="reference" id="cite_ref-TobaccoAtlas_10-0"><a href="#cite_note-TobaccoAtlas-10">[10]</a></sup>
# </caption>
# <tbody><tr>
# <th>Rank</th>
# <th>Country</th>
# <th data-sort-type="number" scope="col" style="text-align: right;">
# </th></tr>
# <tr>
# <td>1</td>
# <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="700" data-file-width="1000" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/19/Flag_of_Andorra.svg/22px-Flag_of_Andorra.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/19/Flag_of_Andorra.svg/33px-Flag_of_Andorra.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/19/Flag_of_Andorra.svg/43px-Flag_of_Andorra.svg.png 2x" width="22"/> </span><a href="/wiki/Andorra" title="Andorra">Andorra</a></td>
# <td>6,398.3
# </td></tr>
# <tr>
# <td>2</td>
# ...

# %%
#getting header
th = table.find_all('th')
for i in th:
    print (i.text)
# Out:
# Rank
# Country

# %%
#getting all the  rows of the table
table_rows = table.find_all('tr')

# %%
# creating list of lists (aka list of rows)
table = []

for tr in table_rows:
    td = tr.find_all('td')
    row = [i.text.strip() for i in td]
    table.append(row)
    print(row)
# Out:
# []
# ['1', 'Andorra', '6,398.3']
# ['2', 'Luxembourg', '6,330.9']
# ['3', 'Belarus', '2,911.3']
# ['4', 'North Macedonia', '2,784.9']
# ['5', 'Albania', '2,491.6']
# ['6', 'Belgium', '2,440.9']
# ['7', 'Czech Republic', '2,427.9']
# ['8', 'Jordan', '2,306.1']
# ['9', 'Russia', '2,295.0']
# ['10', 'Syria', '2,291.7']
# ['11', 'Slovenia', '2,236.5']
# ['12', 'Greece', '2,078.6']
# ['13', 'Hungary', '2,060.3']
# ['14', 'China', '2,043.0']
# ['15', 'Lebanon', '2,037.5']
# ['16', 'Armenia', '1,985.7']
# ['17', 'Mongolia', '1,982.5']
# ['18', 'Cyprus', '1,961.4']
# ['19', 'Austria', '1,927.0']
# ['20', 'Georgia', '1,917.7']
# ['21', 'Serbia', '1,898.6']
# ['22', 'Ukraine', '1,849.4']
# ['23', 'Kazakhstan', '1,800.9']
# ['24', 'Turkey', '1,770.7']
# ['25', 'Bosnia and Herzegovina', '1,767.2']
# ['26', 'Estonia', '1,759.9']
# ['27', 'Bulgaria', '1,757.3']
# ['28', 'Moldova', '1,747.2']
# ['29', 'Papua New Guinea', '1,689.3']
# ['30', 'Indonesia', '1,675.5']
# ...

# %%
#convirting into a DataFrame
age = pd.DataFrame(table)
age.head()
# Out:
#       0                1        2
# 0  None             None     None
# 1     1          Andorra  6,398.3
# 2     2       Luxembourg  6,330.9
# 3     3          Belarus  2,911.3
# 4     4  North Macedonia  2,784.9

# %%
#removing two rows and two columns
age = age.iloc[1:,1:]

# %%
age.columns = ['country', 'smoking']

# %%
age.head(200)
# Out:
#                             country  smoking
# 1                           Andorra  6,398.3
# 2                        Luxembourg  6,330.9
# 3                           Belarus  2,911.3
# 4                   North Macedonia  2,784.9
# 5                           Albania  2,491.6
# 6                           Belgium  2,440.9
# 7                    Czech Republic  2,427.9
# 8                            Jordan  2,306.1
# 9                            Russia  2,295.0
# 10                            Syria  2,291.7
# 11                         Slovenia  2,236.5
# 12                           Greece  2,078.6
# 13                          Hungary  2,060.3
# 14                            China  2,043.0
# 15                          Lebanon  2,037.5
# 16                          Armenia  1,985.7
# 17                         Mongolia  1,982.5
# 18                           Cyprus  1,961.4
# 19                          Austria  1,927.0
# 20                          Georgia  1,917.7
# ...

# %%
age.isnull().sum()
# Out:
# country    0
# smoking    0
# dtype: int64

# %%
#looks like we have strings as rank and age 
age.dtypes
# Out:
# country    object
# smoking    object
# dtype: object

# %%
age.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181 entries, 1 to 181
# Data columns (total 2 columns):
# country    181 non-null object
# smoking    181 non-null object
# dtypes: object(2)
# memory usage: 3.0+ KB

# %%
#converting strings into numeric 

age['smoking'] = age['smoking'].str.replace(',','').apply(float)
age.dtypes
# Out:
# country     object
# smoking    float64
# dtype: object

# %%
age.shape
# Out:
# (181, 2)

# %%
age.dropna(inplace=True)
age.reset_index(inplace=True, drop=True)

# %%
age.head(10)
# Out:
#           country  smoking
# 0         Andorra   6398.3
# 1      Luxembourg   6330.9
# 2         Belarus   2911.3
# 3       Macedonia   2784.9
# 4         Albania   2491.6
# 5         Belgium   2440.9
# 6  Czech Republic   2427.9
# 7          Jordan   2306.1
# 8          Russia   2295.0
# 9           Syria   2291.7

# %%
# adjusting the names of the countries to make it consistent accross tables 
# %store -r countries_dict
age['country'] = age['country'].replace(countries_dict)

# %%
# %store -r countries
#checking for different versions of countries names
age.country[~age.country.isin(countries)].head(60)
# Out:
# 4          Albania
# 68     North Korea
# 121    Ivory Coast
# 161       Dominica
# 174      Swaziland
# Name: country, dtype: object

# %%
#lets save/pickle our 'age' dataframe
import pickle

with open('../Data/Pickled/smoking.pkl', 'wb') as picklefile:
    pickle.dump(age, picklefile)
